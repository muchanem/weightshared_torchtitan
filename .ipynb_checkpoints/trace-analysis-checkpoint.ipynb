# %%
import json
import os
import pandas as pd
from pathlib import Path
from hta.trace_diff import LabeledTrace, DeviceType, TraceDiff
from hta.utils.utils import shorten_name, flatten_column_names

# %%
shared_t = LabeledTrace(label="Shared", trace_dir=f"outputs/profile_trace_shared_layer/iteration_100")
baseline_t = LabeledTrace(label="Baseline", trace_dir=f"outputs/profile_trace_shared_layer_matched/iteration_200")
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace.py", line 274, in __call__
#     return parse_trace_file(trace_file, self.cfg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace.py", line 248, in parse_trace_file
#     meta, df, local_symbol_table = parse_trace_dataframe(trace_file_path, cfg)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace_parser.py", line 447, in parse_trace_dataframe
#     meta, df, local_symbol_table = _parse_trace_dataframe_json(trace_file_path, cfg)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace_parser.py", line 352, in _parse_trace_dataframe_json
#     trace_record = parse_trace_dict(trace_file_path)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace_parser.py", line 106, in parse_trace_dict
#     trace_record = json.loads(fh2.read())
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/saturncloud/envs/saturn/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 52956 column 553 (char 3255101)
# """
#
# The above exception was the direct cause of the following exception:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 #shared_t = LabeledTrace(label="Shared", trace_dir=f"outputs/profile_trace_shared/iteration_100")
# ----> 2 baseline_t = LabeledTrace(label="Baseline", trace_dir=f"/home/jovyan/shared/muchane/lingua-repo/torchtitan/weightshared_torchtitan/outputs/profile_trace_shared_layer_matched/iteration_100")
#
# File /opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/trace_diff.py:53, in LabeledTrace.__init__(self, label, t, trace_dir)
#      49 else:
#      50     raise ValueError(
#      51         "either a trace object or a valid trace dir must be provided in LabeledTrace.__init__()"
#      52     )
# ---> 53 self.t.parse_traces()
#      55 self.s_map = pd.Series(self.t.symbol_table.get_sym_id_map())
#      56 self.s_tab = pd.Series(self.t.symbol_table.get_sym_table())
#
# File /opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace.py:547, in Trace.parse_traces(self, max_ranks, use_multiprocessing, use_memory_profiling)
#     545 if len(ranks) > 0:
#     546     use_multiprocessing = use_multiprocessing and len(ranks) > 1
# --> 547     self.parse_multiple_ranks(ranks, use_multiprocessing, use_memory_profiling)
#     549     self.is_parsed = True
#     550 else:
#
# File /opt/saturncloud/envs/saturn/lib/python3.12/site-packages/hta/common/trace.py:495, in Trace.parse_multiple_ranks(self, ranks, use_multiprocessing, use_memory_profiling)
#     493 _parser = _TraceFileParserWrapper(self.parser_config)
#     494 with mp.get_context("fork").Pool(num_procs) as pool:
# --> 495     results = pool.map(_parser, trace_paths, chunksize=1)
#     496 logger.debug(f"finished parallel parsing using {num_procs} processes.")
#     498 # collect the results
#
# File /opt/saturncloud/envs/saturn/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/saturncloud/envs/saturn/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# JSONDecodeError: Expecting value: line 52956 column 553 (char 3255101)

# %%
print(f"available ranks for shared: {shared_t.ranks()}")
print(f"available ranks for baseline: {baseline_t.ranks()}")
print(f"available iterations for shared: {shared_t.iterations()}")
print(f"available iterations for baseline: {baseline_t.iterations()}")
# Out:
# available ranks for control_t: [0, 1, 2, 3, 4, 5, 6, 7]
# available ranks for test_t: [0, 1, 2, 3, 4, 5, 6, 7]
# available ranks for iterations: [99]
# available ranks for iterations: [99]

# %%
df_comp = TraceDiff.compare_traces(baseline_t, shared_t, 0, 0, 99, 99, DeviceType.GPU)
df_comp
# Out:
#                                                     Baseline_counts  \
# name
# Memcpy DtoD (Device -> Device)                                115.0
# Memcpy DtoH (Device -> Pinned)                                  4.0
# Memcpy HtoD (Pageable -> Device)                                3.0
# Memset (Device)                                                48.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             60.0
# ...                                                             ...
# void at::native::vectorized_elementwise_kernel<...              0.0
# void at::native::vectorized_elementwise_kernel<...              0.0
# void cublasLt::splitKreduce_kernel<32, 16, int,...              0.0
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...              0.0
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...              0.0
#
#                                                     Baseline_total_duration  \
# name
# Memcpy DtoD (Device -> Device)                                       1209.0
# Memcpy DtoH (Device -> Pinned)                                          7.0
# Memcpy HtoD (Pageable -> Device)                                       25.0
# Memset (Device)                                                        61.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                   6279.0
# ...                                                                     ...
# void at::native::vectorized_elementwise_kernel<...                      0.0
# void at::native::vectorized_elementwise_kernel<...                      0.0
# void cublasLt::splitKreduce_kernel<32, 16, int,...                      0.0
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...                      0.0
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...                      0.0
#
#                                                     Shared_counts  \
# name
# Memcpy DtoD (Device -> Device)                                187
# Memcpy DtoH (Device -> Pinned)                                  4
# Memcpy HtoD (Pageable -> Device)                                3
# Memset (Device)                                                48
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             24
# ...                                                           ...
# void at::native::vectorized_elementwise_kernel<...            108
# void at::native::vectorized_elementwise_kernel<...             72
# void cublasLt::splitKreduce_kernel<32, 16, int,...             36
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...             24
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...             36
#
#                                                     Shared_total_duration  \
# name
# Memcpy DtoD (Device -> Device)                                     1259.0
# Memcpy DtoH (Device -> Pinned)                                        5.0
# Memcpy HtoD (Pageable -> Device)                                     24.0
# Memset (Device)                                                      57.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                 4305.0
# ...                                                                   ...
# void at::native::vectorized_elementwise_kernel<...                 2624.0
# void at::native::vectorized_elementwise_kernel<...                 2674.0
# void cublasLt::splitKreduce_kernel<32, 16, int,...                   80.0
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...                  835.0
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...                  613.0
#
#                                                     diff_counts  \
# name
# Memcpy DtoD (Device -> Device)                             72.0
# Memcpy DtoH (Device -> Pinned)                              0.0
# Memcpy HtoD (Pageable -> Device)                            0.0
# Memset (Device)                                             0.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -36.0
# ...                                                         ...
# void at::native::vectorized_elementwise_kernel<...        108.0
# void at::native::vectorized_elementwise_kernel<...         72.0
# void cublasLt::splitKreduce_kernel<32, 16, int,...         36.0
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...         24.0
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...         36.0
#
#                                                     diff_duration  \
# name
# Memcpy DtoD (Device -> Device)                               50.0
# Memcpy DtoH (Device -> Pinned)                               -2.0
# Memcpy HtoD (Pageable -> Device)                             -1.0
# Memset (Device)                                              -4.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -1974.0
# ...                                                           ...
# void at::native::vectorized_elementwise_kernel<...         2624.0
# void at::native::vectorized_elementwise_kernel<...         2674.0
# void cublasLt::splitKreduce_kernel<32, 16, int,...           80.0
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...          835.0
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...          613.0
#
#                                                    counts_change_categories
# name
# Memcpy DtoD (Device -> Device)                                            +
# Memcpy DtoH (Device -> Pinned)                                            =
# Memcpy HtoD (Pageable -> Device)                                          =
# Memset (Device)                                                           =
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                        -
# ...                                                                     ...
# void at::native::vectorized_elementwise_kernel<...                        +
# void at::native::vectorized_elementwise_kernel<...                        +
# void cublasLt::splitKreduce_kernel<32, 16, int,...                        +
# void cutlass::Kernel2<cutlass_80_tensorop_bf16_...                        +
# void cutlass::Kernel2<cutlass_80_tensorop_s1681...                        +
#
# [78 rows x 7 columns]

# %%
df_comp.sort_values(by="diff_duration",ascending=False)
# Out:
#                                                     Baseline_counts  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...              5.0
# void at::native::vectorized_elementwise_kernel<...            402.0
# void at::native::vectorized_elementwise_kernel<...             60.0
# void at::native::unrolled_elementwise_kernel<at...            234.0
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...             12.0
# ...                                                             ...
# void at::native::vectorized_elementwise_kernel<...             48.0
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...             12.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             48.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             60.0
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...             72.0
#
#                                                     Baseline_total_duration  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...                  14148.0
# void at::native::vectorized_elementwise_kernel<...                  29683.0
# void at::native::vectorized_elementwise_kernel<...                   6676.0
# void at::native::unrolled_elementwise_kernel<at...                  38338.0
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...                  68928.0
# ...                                                                     ...
# void at::native::vectorized_elementwise_kernel<...                   8434.0
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...                  29225.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                   3154.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                   6279.0
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...                   5330.0
#
#                                                     Shared_counts  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...              5
# void at::native::vectorized_elementwise_kernel<...            618
# void at::native::vectorized_elementwise_kernel<...             96
# void at::native::unrolled_elementwise_kernel<at...            342
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...             12
# ...                                                           ...
# void at::native::vectorized_elementwise_kernel<...             48
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...             12
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             12
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...             24
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...             24
#
#                                                     Shared_total_duration  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...                69505.0
# void at::native::vectorized_elementwise_kernel<...                34021.0
# void at::native::vectorized_elementwise_kernel<...                10975.0
# void at::native::unrolled_elementwise_kernel<at...                42039.0
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...                72460.0
# ...                                                                   ...
# void at::native::vectorized_elementwise_kernel<...                 8304.0
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...                29086.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                 1216.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                 4305.0
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...                 2240.0
#
#                                                     diff_counts  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...          0.0
# void at::native::vectorized_elementwise_kernel<...        216.0
# void at::native::vectorized_elementwise_kernel<...         36.0
# void at::native::unrolled_elementwise_kernel<at...        108.0
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...          0.0
# ...                                                         ...
# void at::native::vectorized_elementwise_kernel<...          0.0
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...          0.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -36.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -36.0
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...        -48.0
#
#                                                     diff_duration  \
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...        55357.0
# void at::native::vectorized_elementwise_kernel<...         4338.0
# void at::native::vectorized_elementwise_kernel<...         4299.0
# void at::native::unrolled_elementwise_kernel<at...         3701.0
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...         3532.0
# ...                                                           ...
# void at::native::vectorized_elementwise_kernel<...         -130.0
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...         -139.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -1938.0
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...        -1974.0
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...        -3090.0
#
#                                                    counts_change_categories
# name
# ncclDevKernel_AllReduce_Sum_f32_RING_LL(ncclDev...                        =
# void at::native::vectorized_elementwise_kernel<...                        +
# void at::native::vectorized_elementwise_kernel<...                        +
# void at::native::unrolled_elementwise_kernel<at...                        +
# void pytorch_flash::flash_bwd_dq_dk_dv_loop_seq...                        =
# ...                                                                     ...
# void at::native::vectorized_elementwise_kernel<...                        =
# void pytorch_flash::flash_fwd_kernel<Flash_fwd_...                        =
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                        -
# ampere_bf16_s16816gemm_bf16_128x128_ldg8_f2f_st...                        -
# ampere_bf16_s16816gemm_bf16_256x128_ldg8_f2f_st...                        -
#
# [78 rows x 7 columns]

# %%
shorten_name("void at::native::vectorized_elementwise_kernel<4, at::native::bfloat16_copy_kernel_cuda(at::TensorIteratorBase&)::{lambda(float)#1}, std::array<char*, 2ul> >(int, at::native::bfloat16_copy_kernel_cuda(at::TensorIteratorBase&)::{lambda(float)#1}, std::array<char*, 2ul>)	")
# Out:
# 'at::native::vectorized_elementwise_kernel\t'
